# %% [markdown]
# # Single Layer Neural Network for Binary Classification

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generate Dataset
# - x1, x2는 -1.0 ~ 1.0의 값을 가지는 균등분포로 랜덤 생성

# %%
x1 = np.random.uniform(low=-1.0, high=1.0, size=100)

print(x1.shape)
x1[0:10]
# Out:
# (100,)
# array([ 0.57902063,  0.13958043,  0.99260804, -0.5713393 ,  0.02625413,
#         0.79895229, -0.78573621,  0.6424325 , -0.96216847,  0.96087575])

# %%
x2 = np.random.uniform(low=-1.0, high=1.0, size=100)

print(x2.shape)
x2[0:10]
# Out:
# (100,)
# array([-0.0340783 ,  0.36312207,  0.43772151,  0.31506002,  0.91978381,
#        -0.17394865,  0.75403075,  0.8496424 ,  0.96140408,  0.84136365])

# %% [markdown]
# - y = 0.3 * x1 + 0.5 * x2 +0.1 이며, 음수와 양수로 나눔(True/False)

# %%
y = 0.3 * x1 + 0.5 * x2 + 0.1
y = y > 0.0

print(y.shape)
y[0:10]
# Out:
# (100,)
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
plt.scatter(x1, x2, c=y)

# %% [markdown]
# ## Define Sigmoid (시그모이드 활성함수)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
xx = np.linspace(-10, 10, num=21)
yy = sigmoid(xx)

plt.plot(xx, yy)

# %% [markdown]
# ## Gradient Descent (derror/dweight)

# %%
num_epoch = 100
learning_rate = 1.0

w1 = np.random.uniform(low=0.0, high=1.0)
w2 = np.random.uniform(low=0.0, high=1.0)
b = np.random.uniform(low=0.0, high=1.0)

for epoch in range(num_epoch):
    y_predict = w1 * x1 + w2 * x2 + b
    y_predict = sigmoid(y_predict)
    
    predict = y_predict > 0.5
    error = (predict != y).mean()
    
    if epoch % 10 == 0:
        print("{0:2} error = {1:.6f}".format(epoch, error))
    
    if error < 0.03:
        break

    w1 = w1 - learning_rate * ((y_predict - y) * x1).mean()
    w2 = w2 - learning_rate * ((y_predict - y) * x2).mean()
    b = b - learning_rate * (y_predict - y).mean()

print("----" * 10)
print("w1 = {0:.6f}, w2 = {1:.6f} b = {2:.6f}".format(w1, w2, b))
print("{0:2} error = {1:.6f}".format(epoch, error))
# Out:
#  0 error = 0.250000
# 10 error = 0.080000
# 20 error = 0.040000
# ----------------------------------------
# w1 = 1.300934, w2 = 2.926257 b = 0.988680
# 29 error = 0.020000

# %%
import pandas as pd

y_predict = w1 * x1 + w2 * x2 + b
y_predict = sigmoid(y_predict)
y_predict = y_predict > 0.5

result = pd.DataFrame({'x1': x1, 'x2': x2, 'y(actual)': y, 'y(predict)': y_predict})
result
# Out:
#           x1        x2  y(actual)  y(predict)
# 0   0.579021 -0.034078       True        True
# 1   0.139580  0.363122       True        True
# 2   0.992608  0.437722       True        True
# 3  -0.571339  0.315060       True        True
# 4   0.026254  0.919784       True        True
# 5   0.798952 -0.173949       True        True
# 6  -0.785736  0.754031       True        True
# 7   0.642433  0.849642       True        True
# 8  -0.962168  0.961404       True        True
# 9   0.960876  0.841364       True        True
# 10 -0.342186  0.801977       True        True
# 11 -0.383071 -0.523622      False       False
# 12  0.269178 -0.717633      False       False
# 13 -0.287429  0.873018       True        True
# 14  0.464675 -0.274617       True        True
# 15 -0.354005  0.784710       True        True
# 16  0.673956  0.052915       True        True
# 17 -0.854187 -0.009899      False       False
# 18 -0.244952  0.418664       True        True
# 19 -0.142629 -0.390646      False       False
# 20 -0.456321 -0.743708      False       False
# 21 -0.717024  0.424364       True        True
# 22  0.964928  0.984153       True        True
# 23  0.948153 -0.127237       True        True
# 24  0.537940  0.725851       True        True
# 25  0.033575  0.779540       True        True
# 26  0.054437 -0.591607      False       False
# 27  0.835131  0.416625       True        True
# 28 -0.425712  0.006265      False        True
# 29  0.071911 -0.460287      False       False
# ..       ...       ...        ...         ...
# 70 -0.281026 -0.020369       True        True
# 71  0.828405 -0.614787       True        True
# 72 -0.009209 -0.050746       True        True
# 73 -0.478426 -0.615303      False       False
# 74  0.026399 -0.350545      False       False
# 75  0.148980 -0.120278       True        True
# 76  0.805470 -0.588674       True        True
# 77 -0.182323  0.103062       True        True
# 78 -0.779071  0.928798       True        True
# 79  0.796232 -0.149063       True        True
# 80  0.907665  0.716222       True        True
# 81  0.575500 -0.526474       True        True
# 82  0.178774  0.633712       True        True
# 83  0.845455 -0.828865      False       False
# 84 -0.646956  0.282289       True        True
# 85 -0.548547 -0.722000      False       False
# 86  0.604909  0.501550       True        True
# 87 -0.450758 -0.946507      False       False
# 88 -0.967988 -0.238250      False       False
# 89  0.369809  0.564271       True        True
# 90  0.326584  0.089514       True        True
# 91  0.765838  0.536383       True        True
# 92  0.629826  0.844731       True        True
# 93 -0.404741  0.569566       True        True
# 94 -0.298548  0.464271       True        True
# 95  0.696432 -0.659160      False       False
# 96  0.624722 -0.998035      False       False
# 97  0.949413  0.422641       True        True
# 98  0.079516  0.145440       True        True
# 99 -0.667534 -0.363210      False       False
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 100개중 98개 정확한 예측

# %%
result["accuracy"] = result["y(actual)"] == result["y(predict)"]

# %%
result["accuracy"].sum()
# Out:
# 98
